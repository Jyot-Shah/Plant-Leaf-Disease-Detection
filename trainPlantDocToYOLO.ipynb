# %% [markdown]
# Download Dataset

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="your_roboflow_api_key")
project = rf.workspace("workspace1-qu3qq").project("plantdoc-rcmou-z1s3f")
version = project.version(1)
dataset = version.download("yolov11")

# %% [markdown]
# Train Model

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")

results = model.train(data="plantdoc-1/data.yaml", epochs=50, batch = 32) # tweak according to your needs

# %% [markdown]
# Test trained model

# %%
model = YOLO("/content/runs/detect/train/weights/best.pt")

results = model.predict(source="/content/plantdoc-1/test/images", save=True, stream=True)

for result in results:
  pass

# %% [markdown]
# Print Metrics

# %%
# Print model metrics
print("=" * 50)
print("Model Metrics:")
print("=" * 50)

# Validate the model and get metrics
metrics = model.val()
print(f"mAP50: {metrics.box.map50}")
print(f"mAP50-95: {metrics.box.map}")
print(f"Precision: {metrics.box.mp}")
print(f"Recall: {metrics.box.mr}")
print("=" * 50)

# Print model information
print(model.info())  # Prints model summary
print(model.names)   # Prints class names
